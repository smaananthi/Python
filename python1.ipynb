# %% [markdown]
# # Python 1
# 1. Print Operation
# 2. Emoji
# 3. Arithmetic operation
# 4. Relational operator
# 5. Logical operator
# 6. Precedence of operator
# 7. string
# 8. length
# 9. Set
# 10. Tuple
# 11. list
# 12. Dictonary

# %% [markdown]
# ## Print Operation

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello'+'!!')
# Out:
# Hello!!

# %%
print("hi!!")
# Out:
# hi!!

# %%
print(1)
# Out:
# 1

# %%
print(1,2)
# Out:
# 1 2

# %% [markdown]
# ## Emoji

# %%
print('\N{thinking face}')
# Out:
# 🤔

# %%
print('\N{smiling face with smiling eyes}')
# Out:
# 😊

# %%
print('\N{grinning face}')
# Out:
# 😀

# %%
print('\N{smiling face with halo}')
# Out:
# 😇

# %% [markdown]
# ## Arithmetic operation

# %%
from PIL import Image

# %%
img=Image.open("i1.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=634x351 at 0x2823246D100>

# %%
a=5
b=6
d=a+b
print("sum=",d)
# Out:
# sum= 11

# %%
a=int(input("Enter the value of a: "))
b=int(input("Enter the value of b: "))
add=a+b
sub=a-b
mul=a*b
div=a/b
print("add: {0},sub: {1},mul:{2},div:{3}".format(add,sub,mul,div)) #using format
# Out:
# Enter the value of a: 5
# Enter the value of b: 3
# add: 8,sub: 2,mul:15,div:1.6666666666666667

# %%
#using padding and precision
print("add: %d,sub: %d, mul: %d,div:%25.3f"%(add,sub,mul,div))
# Out:
# add: 8,sub: 2, mul: 15,div:                    1.667

# %%
#allignment or print table
print('{0:<4}|{1:<4}|{2:<4}|{3:<4}'.format('add','sub','mul','div'))
print('{0:<4}|{1:<4}|{2:<4}|{3:|<4}'.format(add,sub,mul,div))
# Out:
# add |sub |mul |div
# 8   |2   |15  |1.6666666666666667

# %% [markdown]
# ## Relational operator

# %%
img1=Image.open("i2.png")
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=731x264 at 0x28232568970>

# %% [markdown]
# The symbol == coresponds to the equality operators and should not confused with = , the assignment operator

# %% [markdown]
# ## Logical operator

# %%
img2=Image.open("i3.webp")
img2
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=700x224 at 0x28232576040>

# %% [markdown]
# ## Precedence of operator

# %%
img3=Image.open("i4.jpg")
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=643x541 at 0x2822F5F5CA0>

# %% [markdown]
# ## string

# %%
a='nila'
b='kavi'
print(b+a)
# Out:
# kavinila

# %%
print(len(a))
# Out:
# 4

# %% [markdown]
# we ca use single, double, triple for string

# %%
#multiplication using string
a='d'
b=a*55
b
# Out:
# 'ddddddddddddddddddddddddddddddddddddddddddddddddddddddd'

# %% [markdown]
# ## iloc vs String

# %%
a="nila"
print(a[3]) #identifing the element base on index
print(a[2:]) #grab the remaing elements except upto the index
print(a[:2]) #grab the elements upto the index
print(a[-1]) #grab the last element
print(a[:-1]) #grab the element except last element
print(a[::-2]) #grab everything with 2 steps
print(a[::-1])  #print string backwards
# Out:
# a
# la
# ni
# a
# nil
# ai
# alin

# %%
b="157"
print(b[:1]) #first value
print(b[:2]) #first two values
print(b[1:]) #except first value
print(b[2:]) #except first two
print(b[:-1]) #except last one
print(b[:-2]) #except last two
print(b[-1:]) #last element
print(b[-2:]) # last two 
print(b[::-1])
print(b[::-2])
# Out:
# 1
# 15
# 57
# 7
# 15
# 1
# 7
# 57
# 751
# 71

# %%
a="nila"
print(a.upper())
print(a.lower())
# Out:
# NILA
# nila

# %%
a= "MASTER class"
b=a.split()
print(b)
print(b[0])
# Out:
# ['MASTER', 'class']
# MASTER

# %%
c="ElonMusk, stevejobs, billgates"
d=c.split(",")
print(d)
print(d[1])
# Out:
# ['ElonMusk', ' stevejobs', ' billgates']
#  stevejobs

# %%
x='first line
second line
third line'  #we will have syntaxerror
print(x)
# Out:
#   Input In [27]
#     x='first line
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
x='''first line
second line
third line'''
print(x)
# Out:
# first line
# second line
# third line

# %% [markdown]
# ## Length

# %%
x='good'
print(len(x))
# Out:
# 4

# %%
x=''
print(x)

# %% [markdown]
# ## operations of string

# %% [markdown]
# ### 1. concatenation (+)

# %%
s1='first'
s2=','
s3='second'
string=s1+s2+s3
print(string)
# Out:
# first,second

# %% [markdown]
# ### 2. Replication (*)

# %%
s='nice'
s1=s*5
print(s1)
# Out:
# nicenicenicenicenice

# %% [markdown]
# ### 3. Comparison (==)

# %%
x='python'
print(x=='python', x=='hiomk')
# Out:
# True False

# %% [markdown]
# ### 4. Escape character

# %%
x='\n'
print(len(x))
# Out:
# 1

# %%
print('a\tb')
# Out:
# a	b

# %%
a='abc'
b='ab'
print(a not in b)
# Out:
# True

# %%
email='cs_10_014@iitm.ac.in'
roll=email[6:9]
print(roll)
# Out:
# 014

# %%
rol=email[3:9]
print(rol)
# Out:
# 10_014

# %%
rol1=email[8:10]
print(rol1)
# Out:
# 4@

# %% [markdown]
# ## Set & Tuple & list & Dictonary

# %% [markdown]
# #### Set
# 1. unordered collection of data
# 2. curly braces{}
# 3. mutable | no duplicates
# 4. use add command
# 5. pop- remove the random element
# 6. cannot be sorted
# 7. cannot get index
# 8. cannot be reversed

# %%
# create a set of string type
set={'a','e','i','o','u'}
print('set=',set)
# Out:
# set= {'a', 'u', 'e', 'i', 'o'}

# %%
set.add('b'+'z')
set
# Out:
# {'a', 'bz', 'e', 'i', 'o', 'u'}

# %%
set.add('p')
set
# Out:
# {'a', 'bz', 'e', 'i', 'o', 'p', 'u'}

# %%
# create a set of integer type
student_id = {112, 114, 116, 118, 115}
print('Student ID:', student_id)
# Out:
# Student ID: {112, 114, 115, 116, 118}

# %%
# create a set of mixed data types
mixed_set = {'hi', 1.2, -2, 'to'}
print('Set of mixed data types:', mixed_set)
# Out:
# Set of mixed data types: {'hi', 1.2, 'to', -2}

# %%
# first set
A = {1, 3, 5}

# second set
B = {0, 2, 4}

# perform union operation using |
print('Union using |:', A | B)

# perform union operation using union()
print('Union using union():', A.union(B))
# Out:
# Union using |: {0, 1, 2, 3, 4, 5}
# Union using union(): {0, 1, 2, 3, 4, 5}

# %%
# first set
A = {1, 3, 5}

# second set
B = {1, 2, 3}

# perform intersection operation using &
print('Intersection using &:', A & B)

# perform intersection operation using intersection()
print('Intersection using intersection():', A.intersection(B))
# Out:
# Intersection using &: {1, 3}
# Intersection using intersection(): {1, 3}

# %%
# first set
A = {2, 3, 5}

# second set
B = {1, 2, 6}

# perform difference operation using &
print('Difference using &:', A - B)

# perform difference operation using difference()
print('Difference using difference():', A.difference(B))
# Out:
# Difference using &: {3, 5}
# Difference using difference(): {3, 5}

# %%
# first set
A = {2, 3, 5}

# second set
B = {1, 2, 6}

# perform difference operation using &
print('using ^:', A ^ B)

# using symmetric_difference()
print('using symmetric_difference():', A.symmetric_difference(B))
# Out:
# using ^: {1, 3, 5, 6}
# using symmetric_difference(): {1, 3, 5, 6}

# %%
# first set
A = {1, 3, 5}

# second set
B = {3, 5, 1}

# perform difference operation using &
if A == B:
    print('Set A and Set B are equal')
else:
    print('Set A and Set B are not equal')
# Out:
# Set A and Set B are equal

# %% [markdown]
# #### Tuple
# 1. ordered collection of data
# 2. patenthesis()
# 3. imutable
# 4. cannot added
# 5. specific element cannot be removed
# 6. already sorted
# 7. index - searching given element which returns the position
# 8. cannot be reversed

# %%
t=("high","medium","low")
print(t)
# Out:
# ('high', 'medium', 'low')

# %%
#allow duplicate
t=("high","medium","low","high")
print(t)
# Out:
# ('high', 'medium', 'low', 'high')

# %%
print(len(t))
# Out:
# 4

# %% [markdown]
# #### list
# 1. collection of ordered data
# 2. square braces[]
# 3. mutable - we can remove or add elements to it
# 4. append-add element
# 5. pop- remove the element
# 6. sort- sorting elements
# 7. index-searching given element
# 8. reverse- reverse the element

# %%
list = ["apple", "banana", "cherry"]
print(list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#allow duplicate
list = ["apple", "banana", "cherry","apple"]
print(list)
# Out:
# ['apple', 'banana', 'cherry', 'apple']

# %%
print(len(list))
# Out:
# 4

# %%
#list contain different data type
list1 = ["abc", 34, True, 40, "male"]
list1
# Out:
# ['abc', 34, True, 40, 'male']

# %% [markdown]
# #### Dictonary
# 1. unordered collection which stores data in KEY,VALUE Basis
# 2. curly braces{}
# 3. mutable | no duplicates
# 4. update- add value
# 5. pop-remove the specified element
# 6. sorted - sorting keys DEFAULT
# 7. get - return value with element key
# 8. cannot be reversed

# %%
dict = {
  "brand": "hero",
  "model": "345",
  "year": 2000
}
dict
# Out:
# {'brand': 'hero', 'model': '345', 'year': 2000}

# %%
print(dict['brand'])
# Out:
# hero

# %%
#add duplicate
dict = {
  "brand": "hero",
  "model": "4582",
  "year": 2000,
  "year": 2020
}
print(dict)
# Out:
# {'brand': 'hero', 'model': '4582', 'year': 2020}

# %%
#changing in dic
a={"Name":"Elon", "Age":50,"company":["spaceX","Tesla"]}
print(a["Name"]) #printing value based on its key
a["Age"]=51
a
# Out:
# Elon
# {'Name': 'Elon', 'Age': 51, 'company': ['spaceX', 'Tesla']}
